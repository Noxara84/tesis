# %%
import matplotlib.pyplot as plt
import nest
import numpy as np

# %%
import matplotlib.pyplot as plt
neuron_hh = nest.Create("hh_psc_alpha")
neuron_hh.I_e = 1000
multimeter_hh = nest.Create("multimeter")
multimeter_hh.set(record_from=["V_m"])
nest.Connect(multimeter_hh, neuron_hh)
nest.Simulate(100.0)
dmm = multimeter_hh.get()
Vms1 = dmm["events"]["V_m"]
ts1 = dmm["events"]["times"]
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(ts1, Vms1)
# Out:
# Mar 21 01:56:20 NodeManager::prepare_nodes [Info]:
#     Preparing 2 nodes for simulation.
#
# Mar 21 01:56:20 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Mar 21 01:56:20 SimulationManager::run [Info]:
#     Simulation finished.

# %%
import matplotlib.pyplot as plt
neuron_hh = nest.Create("hh_psc_alpha")
neuron_hh.I_e = 10000
multimeter_hh = nest.Create("multimeter")
multimeter_hh.set(record_from=["V_m"])
nest.Connect(multimeter_hh, neuron_hh)
nest.Simulate(100.0)
dmm = multimeter_hh.get()
Vms2 = dmm["events"]["V_m"]
ts2 = dmm["events"]["times"]
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(ts2, Vms2)
# Out:
# Mar 21 02:13:21 NodeManager::prepare_nodes [Info]:
#     Preparing 10 nodes for simulation.
#
# Mar 21 02:13:21 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 10
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Mar 21 02:13:21 SimulationManager::run [Info]:
#     Simulation finished.

# %%
import matplotlib.pyplot as plt
Vms = []
ts = []

neuron_hh = nest.Create("hh_psc_alpha")
neuron_hh.I_e = 0
multimeter_hh = nest.Create("multimeter")
multimeter_hh.set(record_from=["V_m"])
nest.Connect(multimeter_hh, neuron_hh)
nest.Simulate(100.0)
dmm = multimeter_hh.get()
Vms = np.concatenate([Vms,dmm["events"]["V_m"]])
ts = np.concatenate([ts,dmm["events"]["times"]])

neuron_hh = nest.Create("hh_psc_alpha")
neuron_hh.I_e = 1000
multimeter_hh = nest.Create("multimeter")
multimeter_hh.set(record_from=["V_m"])
nest.Connect(multimeter_hh, neuron_hh)
nest.Simulate(100.0)
dmm = multimeter_hh.get()
Vms = np.concatenate([Vms,dmm["events"]["V_m"]])
ts = np.concatenate([ts,dmm["events"]["times"]])

neuron_hh = nest.Create("hh_psc_alpha")
neuron_hh.I_e = 0
multimeter_hh = nest.Create("multimeter")
multimeter_hh.set(record_from=["V_m"])
nest.Connect(multimeter_hh, neuron_hh)
nest.Simulate(100.0)
dmm = multimeter_hh.get()
Vms = np.concatenate([Vms,dmm["events"]["V_m"]])
ts = np.concatenate([ts,dmm["events"]["times"]])

neuron_hh = nest.Create("hh_psc_alpha")
neuron_hh.I_e = 3500
multimeter_hh = nest.Create("multimeter")
multimeter_hh.set(record_from=["V_m"])
nest.Connect(multimeter_hh, neuron_hh)
nest.Simulate(100.0)
dmm = multimeter_hh.get()
Vms = np.concatenate([Vms,dmm["events"]["V_m"]])
ts = np.concatenate([ts,dmm["events"]["times"]])

neuron_hh = nest.Create("hh_psc_alpha")
neuron_hh.I_e = 0
multimeter_hh = nest.Create("multimeter")
multimeter_hh.set(record_from=["V_m"])
nest.Connect(multimeter_hh, neuron_hh)
nest.Simulate(100.0)
dmm = multimeter_hh.get()
Vms = np.concatenate([Vms,dmm["events"]["V_m"]])
ts = np.concatenate([ts,dmm["events"]["times"]])

neuron_hh = nest.Create("hh_psc_alpha")
neuron_hh.I_e = 10000
multimeter_hh = nest.Create("multimeter")
multimeter_hh.set(record_from=["V_m"])
nest.Connect(multimeter_hh, neuron_hh)
nest.Simulate(100.0)
dmm = multimeter_hh.get()
Vms = np.concatenate([Vms,dmm["events"]["V_m"]])
ts = np.concatenate([ts,dmm["events"]["times"]])

plt.figure(figsize=(14, 4), dpi=80)
plt.plot(ts, Vms)
# Out:
# Mar 21 02:16:39 NodeManager::prepare_nodes [Info]:
#     Preparing 60 nodes for simulation.
#
# Mar 21 02:16:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 60
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Mar 21 02:16:39 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 21 02:16:39 NodeManager::prepare_nodes [Info]:
#     Preparing 62 nodes for simulation.
#
# Mar 21 02:16:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 62
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Mar 21 02:16:39 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 21 02:16:39 NodeManager::prepare_nodes [Info]:
#     Preparing 64 nodes for simulation.
#
# Mar 21 02:16:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 64
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Mar 21 02:16:39 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 21 02:16:39 NodeManager::prepare_nodes [Info]:
#     Preparing 66 nodes for simulation.
#
# Mar 21 02:16:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 66
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Mar 21 02:16:39 SimulationManager::run [Info]:
#     Simulation finished.
#
# Mar 21 02:16:39 NodeManager::prepare_nodes [Info]:
#     Preparing 68 nodes for simulation.
#
# Mar 21 02:16:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 68
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Mar 21 02:16:39 SimulationManager::run [Info]:
#     Simulation finished.
# Mar 21 02:16:39 NodeManager::prepare_nodes [Info]:
#     Preparing 70 nodes for simulation.
#
# Mar 21 02:16:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 70
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Mar 21 02:16:39 SimulationManager::run [Info]:
#     Simulation finished.

# %%
ts3=np.concatenate([ts1,ts2])
Vms3 = np.concatenate([Vms1,Vms2])
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(ts3, Vms3)

# %%
import matplotlib.pyplot as plt
neuron_hh = nest.Create("hh_psc_alpha")
neuron_hh.I_e = 300
multimeter_hh = nest.Create("multimeter")
multimeter_hh.set(record_from=["V_m"])
nest.Connect(multimeter_hh, neuron_hh)
nest.Simulate(100.0)
dmm = multimeter_hh.get()
Vms = dmm["events"]["V_m"]
ts = dmm["events"]["times"]
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(ts, Vms)
# Out:
# Mar 21 01:56:20 NodeManager::prepare_nodes [Info]:
#     Preparing 6 nodes for simulation.
#
# Mar 21 01:56:20 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 6
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Mar 21 01:56:20 SimulationManager::run [Info]:
#     Simulation finished.
