# %%
import matplotlib.pyplot as plt
import nest
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: compiletime version 3.8 of module 'pynestkernel' does not match runtime version 3.9
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.2
#  Built: Feb 10 2022 07:14:50
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
import matplotlib.pyplot as plt
neuron_hh = nest.Create("hh_psc_alpha")
neuron_hh.I_e = 1000
multimeter_hh = nest.Create("multimeter")
multimeter_hh.set(record_from=["V_m"])
nest.Connect(multimeter_hh, neuron_hh)
nest.Simulate(100.0)
dmm = multimeter_hh.get()
Vms1 = dmm["events"]["V_m"]
ts1 = dmm["events"]["times"]
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(ts1, Vms1)
# Out:
# Mar 21 01:56:20 NodeManager::prepare_nodes [Info]:
#     Preparing 2 nodes for simulation.
#
# Mar 21 01:56:20 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Mar 21 01:56:20 SimulationManager::run [Info]:
#     Simulation finished.

# %%
import matplotlib.pyplot as plt
neuron_hh = nest.Create("hh_psc_alpha")
neuron_hh.I_e = 10000
multimeter_hh = nest.Create("multimeter")
multimeter_hh.set(record_from=["V_m"])
nest.Connect(multimeter_hh, neuron_hh)
nest.Simulate(100.0)
dmm = multimeter_hh.get()
Vms2 = dmm["events"]["V_m"]
ts2 = dmm["events"]["times"]
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(ts2, Vms2)
# Out:
# Mar 21 01:56:20 NodeManager::prepare_nodes [Info]:
#     Preparing 4 nodes for simulation.
#
# Mar 21 01:56:20 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 4
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Mar 21 01:56:20 SimulationManager::run [Info]:
#     Simulation finished.

# %%
ts3=ts1+ts2
Vms3=numpy.concatenate(Vms1,Vms2) 
Vms3
# Out:
# array([ -18.12007266,   18.75051312,  -46.66104294, -108.30996207,
#        -135.7218267 , -129.6434002 , -122.44801612, -107.5262945 ,
#         -79.34635706, -111.31359385, -127.1955751 , -120.87033988,
#        -114.13861318, -106.5539503 ,  -91.14687296,  -70.33065929,
#         -19.02646676,  -72.9051797 , -118.9932949 , -126.44611949,
#        -119.1510513 , -102.33815761,  -94.38808196, -120.3770028 ,
#        -125.67786446, -119.14389653, -112.42419828, -103.87342993,
#         -83.84976028,  -85.37307387, -102.52611939,  -37.71396167,
#         -82.79816259, -123.63972963, -115.81940833,  -94.41753516,
#        -106.79750224, -128.72044449, -125.08813697, -118.34112069,
#        -111.19131564,  -99.8717759 ,  -79.36077015,  -98.80783177,
#        -114.17062353,  -78.64426236,  -50.06147484,  -92.29182559,
#        -109.80572358,  -95.56216239, -119.74490169, -130.73804337,
#        -124.47902974, -117.61517274, -109.48197055,  -92.51054753,
#         -86.46813041, -111.81332716, -115.9554869 , -105.76626816,
#         -19.84547173,  -59.1343527 ,  -91.93731807, -105.80978857,
#        -130.82831141, -130.40633351, -123.83882824, -116.74371469,
#        -106.51263951,  -84.55949266,  -98.65119854, -119.76645404,
#        -115.74560955, -108.19681558,  -90.83053726,  -20.86139723,
#         -52.31032412, -117.54106988, -134.64796957, -129.57929709,
#        -123.10335965, -115.43693894, -100.78561703,  -87.36929206,
#        -111.67317697, -121.20210566, -115.07492201, -108.1785917 ,
#         -97.98769329,  -35.91019687,  -29.17990155, -104.49592682,
#        -134.26229281, -128.56326905, -122.14072634, -113.12117553,
#         -92.0828677 ,  -98.64836334, -122.34898682])

# %%
import matplotlib.pyplot as plt
neuron_hh = nest.Create("hh_psc_alpha")
neuron_hh.I_e = 300
multimeter_hh = nest.Create("multimeter")
multimeter_hh.set(record_from=["V_m"])
nest.Connect(multimeter_hh, neuron_hh)
nest.Simulate(100.0)
dmm = multimeter_hh.get()
Vms = dmm["events"]["V_m"]
ts = dmm["events"]["times"]
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(ts, Vms)
# Out:
# Mar 21 01:56:20 NodeManager::prepare_nodes [Info]:
#     Preparing 6 nodes for simulation.
#
# Mar 21 01:56:20 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 6
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Mar 21 01:56:20 SimulationManager::run [Info]:
#     Simulation finished.
